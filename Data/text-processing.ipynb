# %% [markdown]
# # Text Processing Experiments

# %%
pwd
# Out:
# 'C:\\Users\\Mechachleopteryx\\academizer'

# %%
# !pip install jvm
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Using cached packaging-23.2-py3-none-any.whl (53 kB)
# ...
#   Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# ...
#   Created wheel for jni: filename=jni-1.0.0b20-cp38-cp38-win_amd64.whl size=105280 sha256=f79e3e0f412468c6df44c0dd9ee0e930d7410ad0d5e116648cf6fc58595553a9
#   Stored in directory: c:\users\mechachleopteryx\appdata\local\pip\cache\wheels\81\37\0f\8a0e916e7d468013d42d3c42fcf2ecc5a20bd47d26ca1247b0
# Successfully built jni
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.4
#     Uninstalling packaging-20.4:
# ERROR: nibabel 5.1.0 has requirement numpy>=1.19, but you'll have numpy 1.18.5 which is incompatible.
# ...

# %%
# !pip install aspose-cells
# Out:
# ...
#   Created wheel for aspose-cells: filename=aspose_cells-23.11.0-py3-none-any.whl size=14135498 sha256=bbf9ceae9dae5eacee51ff523854ac478869e7e3bb272d1d8a3a5182380af016
#   Stored in directory: c:\users\mechachleopteryx\appdata\local\pip\cache\wheels\a6\3d\8d\e177645822ae18839a7d5927da48386e0ce6deccc94235b7e2
# Successfully built aspose-cells
# ...

# %%
# !pip install jpype1

# %%
import jpype
import asposecells
from asposecells.api import Workbook
import json
import os

# Function to process a limited portion of each MHTML file
def process_mhtml_file(file_path, limit_pages):
    workbook = Workbook(file_path)
    # Implement your logic here to process only 'limit_pages' amount of content
    # Return the extracted content

# Start the JVM
jpype.startJVM()

# Get the current working directory
directory = os.getcwd()
file_count = 0
results = []

# Find and process the first 10 .mhtml files
for filename in os.listdir(directory):
    if filename.endswith(".mhtml") and file_count < 10:
        file_path = os.path.join(directory, filename)
        extracted_content = process_mhtml_file(file_path, limit_pages=10)
        results.append(extracted_content)
        file_count += 1
        # Display results in the notebook
        print(f"Processed {filename}:")
        print(json.dumps(extracted_content, indent=4))
        print("\n------------------------------------------------\n")

# Shutdown JVM
jpype.shutdownJVM()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-912a46c26015> in <module>
#       1 import jpype
#       2 import asposecells
# ----> 3 from asposecells.api import Workbook
#       4 import json
#       5 import os
#
# C:\ProgramData\Anaconda3\lib\site-packages\asposecells\api.py in <module>
#       8 from jpype import imports
#       9
# ---> 10 from com.aspose.cells.wrapper import StreamBuffer
#      11 @JImplementationFor("com.aspose.cells.wrapper.StreamBuffer")
#      12 class _StreamBuffer(object):
#
# C:\ProgramData\Anaconda3\lib\site-packages\jpype\imports.py in find_spec(self, name, path, target)
#     153             if not base in _JDOMAINS:
#     154                 return None
# --> 155             raise ImportError("Attempt to create Java package '%s' without jvm" % name)
#     156
#     157         # Check for aliases
#
# ...

# %%
import jpype
import asposecells
import os
import json

# Specify the path to the JVM
jvm_path = jpype.getDefaultJVMPath()

# Start the JVM with the specified path
jpype.startJVM(jvm_path)

# Import Workbook from asposecells after starting JVM
from asposecells.api import Workbook

# Function to process a limited portion of each MHTML file
def process_mhtml_file(file_path, limit_pages):
    workbook = Workbook(file_path)
    # Implement your logic here to process only 'limit_pages' amount of content
    # Return the extracted content

# Get the current working directory
directory = os.getcwd()
file_count = 0
results = []

# Find and process the first 10 .mhtml files
for filename in os.listdir(directory):
    if filename.endswith(".mhtml") and file_count < 10:
        file_path = os.path.join(directory, filename)
        extracted_content = process_mhtml_file(file_path, limit_pages=10)
        results.append(extracted_content)
        file_count += 1
        # Display results in the notebook
        print(f"Processed {filename}:")
        print(json.dumps(extracted_content, indent=4))
        print("\n------------------------------------------------\n")

# Shutdown JVM
jpype.shutdownJVM()
# Out:
# Processed A Convoluted Mirror.mhtml:
# null
#
# ------------------------------------------------
#
# Processed A Hyper-Dimensional Primer on Logical Constructs.mhtml:
# null
#
# ------------------------------------------------
#
# Processed A Scientific Mindset.mhtml:
# null
#
# ------------------------------------------------
#
# Processed About Brain-Centricism.mhtml:
# null
#
# ------------------------------------------------
#
# Processed Abstract Algebra One.mhtml:
# null
#
# ------------------------------------------------
#
# Processed Abstract Algebra Two.mhtml:
# null
#
# ------------------------------------------------
#
# Processed Abstract Symbolic Distillation.mhtml:
# null
#
# ------------------------------------------------
#
# Processed Academizer.mhtml:
# null
#
# ------------------------------------------------
#
# Processed Accélération du changement social.mhtml:
# null
#
# ------------------------------------------------
#
# ...

# %%
import os

directory = os.getcwd()  # Current directory
file_count = 0

for filename in os.listdir(directory):
    if filename.endswith(".mhtml") and file_count < 10:
        base = os.path.splitext(filename)[0]
        new_filename = base + ".html"
        os.rename(os.path.join(directory, filename), os.path.join(directory, new_filename))
        file_count += 1
        print(f"Renamed '{filename}' to '{new_filename}'")

print("Renaming complete. You can now try opening these files in a web browser.")
# Out:
# Renamed 'A Convoluted Mirror.mhtml' to 'A Convoluted Mirror.html'
# Renamed 'A Hyper-Dimensional Primer on Logical Constructs.mhtml' to 'A Hyper-Dimensional Primer on Logical Constructs.html'
# Renamed 'A Scientific Mindset.mhtml' to 'A Scientific Mindset.html'
# Renamed 'About Brain-Centricism.mhtml' to 'About Brain-Centricism.html'
# Renamed 'Abstract Algebra One.mhtml' to 'Abstract Algebra One.html'
# Renamed 'Abstract Algebra Two.mhtml' to 'Abstract Algebra Two.html'
# Renamed 'Abstract Symbolic Distillation.mhtml' to 'Abstract Symbolic Distillation.html'
# Renamed 'Academizer.mhtml' to 'Academizer.html'
# Renamed 'Accélération du changement social.mhtml' to 'Accélération du changement social.html'
# Renamed 'Action Theory Resolving Problems.mhtml' to 'Action Theory Resolving Problems.html'
# Renaming complete. You can now try opening these files in a web browser.

# %%
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup
import os

def extract_html_content(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        soup = BeautifulSoup(file, 'html.parser')
        # Extract text or specific elements as needed
        text = soup.get_text()
        return text
directory = os.getcwd()  # Current directory
results = {}

for filename in os.listdir(directory):
    if filename.endswith(".html"):
        file_path = os.path.join(directory, filename)
        content = extract_html_content(file_path)
        results[filename] = content

# Print results or process them as needed
for filename, content in results.items():
    print(f"Content of {filename}:")
    print(content[:500])  # Print first 500 characters of each file for preview
    print("\n------------------------------------------------\n")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-15-c50d4c489805> in <module>
#      14     if filename.endswith(".html"):
#      15         file_path = os.path.join(directory, filename)
# ---> 16         content = extract_html_content(file_path)
#      17         results[filename] = content
#      18
#
# <ipython-input-15-c50d4c489805> in extract_html_content(file_path)
#       4 def extract_html_content(file_path):
#       5     with open(file_path, 'r', encoding='utf-8') as file:
# ----> 6         soup = BeautifulSoup(file, 'html.parser')
#       7         # Extract text or specific elements as needed
#       8         text = soup.get_text()
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     304
# ...

# %%
from bs4 import BeautifulSoup
import os

def extract_html_content(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            soup = BeautifulSoup(file, 'html.parser')
            text = soup.get_text()
            return text
    except UnicodeDecodeError:
        with open(file_path, 'r', encoding='ISO-8859-1') as file:  # Try a different encoding
            soup = BeautifulSoup(file, 'html.parser')
            text = soup.get_text()
            return text

directory = os.getcwd()  # Replace with your directory path
results = {}

for filename in os.listdir(directory):
    if filename.endswith(".html"):
        file_path = os.path.join(directory, filename)
        content = extract_html_content(file_path)
        results[filename] = content

# Print results
for filename, content in results.items():
    print(f"Content of {filename}:")
    print(content[:500])  # Print first 500 characters for preview
    print("\n------------------------------------------------\n")
# Out:
# Content of A Convoluted Mirror.html:
# From:
# Snapshot-Content-Location: https://chat.openai.com/c/91ee8e96-f8ab-4d7c-9bfd-506931d2d6d9
# Subject: A Convoluted Mirror
# Date: Sun, 8 Oct 2023 12:20:26 -0000
# MIME-Version: 1.0
# Content-Type: multipart/related;
# 	type="text/html";
# 	boundary="----MultipartBoundary--Rpd995nOuLn1qZdF6PmDM7HphxSSEtRuCOQt2ilmhH----"
#
#
# ------MultipartBoundary--Rpd995nOuLn1qZdF6PmDM7HphxSSEtRuCOQt2ilmhH----
# Content-Type: text/html
# Content-ID:
# Content-Transfer-Encoding: binary
# Content-Location: https://chat.openai.co
#
# ------------------------------------------------
#
# Content of A Hyper-Dimensional Primer on Logical Constructs.html:
# From:
# Snapshot-Content-Location: https://chat.openai.com/c/cdb79ba3-ed33-46f2-8746-56362594bfdf
# Subject: A Hyper-Dimensional Primer on Logical Constructs
# Date: Sun, 13 Aug 2023 13:32:39 -0000
# MIME-Version: 1.0
# Content-Type: multipart/related;
# 	type="text/html";
# ...
